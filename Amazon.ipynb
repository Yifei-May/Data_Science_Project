# %%
import requests
import socket
#from requests.adapters import HTTPAdapter
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
#如果第一页的url和第二页开始的url不一样，img的属性也不一样，需要单独爬
req_header = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
    'Cookie':'session-id=459-9422158-4293202; i18n-prefs=CNY; ubid-acbcn=458-1711333-0590306; x-wl-uid=1BVMuH1eD98yTaHxVWUa/As36Kg8hzSgi9dRsHFksFLBOuF4JKeRw9RTxJzJlbZckTnjcQh8hfBQ=; lc-acbcn=zh_CN; session-token="6Uu78o6qyx1yVWI2ZCXdCmmRoBOpdWCjLTbRnWPeyFPJ6rTE1neJX4ROLE2znioK4b147Acg/Vt5+5fy87VS80/cBZ9tIJbcQSe7T34qY+9oRCQIuCJoE8pMMoalIwgjMF1YX93IpelJIo7f4YoXWtBRLc89HSHHbn8XlKiHcgQCY2ezelYFeGNfeJk+Fjr2hsYdwxd1IDOyPFmC2wgvNYjOSXR8wdT3f9SJ6VNrC+98w+nphVNcfA=="; session-id-time=2082787201l; csm-hit=tb:EENB0C0RRGJNBEFBQJN7+s-B4R2DY9NWH2TJMYZVJBX|1587389226614&t:1587389226614&adb:adblk_no',
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'
}
n = 1
url = 'https://www.amazon.cn/-/en/s/ref=lp_100276071_nr_n_2?fst=as%3Aoff&rh=n%3A2016156051%2Cn%3A%212016157051%2Cn%3A865184051%2Cn%3A100275071%2Cn%3A100276071%2Cn%3A1894146071&bbn=100276071&ie=UTF8&qid=1592758552&rnid=100276071'
response = requests.get(url,headers=req_header)
soup = BeautifulSoup(response.text)
srclist = []
for x in soup.find_all(name='img', class_='s-access-image cfMarker'):
    link = x.get('src')
    if '.jpg' in link:
        srclist.append(link)
for imgurl in srclist:
    try:
        urllib.request.urlretrieve(imgurl, '/Users/hu/Desktop/project/img/'+str(n)+'.jpg')
        print('Img',str(n),' is downloaded')
        n += 1
    except:
        print('cannot download')
# Out:
# Img 1  is downloaded
# Img 2  is downloaded
# Img 3  is downloaded
# Img 4  is downloaded
# Img 5  is downloaded
# Img 6  is downloaded
# Img 7  is downloaded
# Img 8  is downloaded
# Img 9  is downloaded
# Img 10  is downloaded
# Img 11  is downloaded
# Img 12  is downloaded
# Img 13  is downloaded
# Img 14  is downloaded
# Img 15  is downloaded
# Img 16  is downloaded
# Img 17  is downloaded
# Img 18  is downloaded
# Img 19  is downloaded
# Img 20  is downloaded
# Img 21  is downloaded
# Img 22  is downloaded
# Img 23  is downloaded
# Img 24  is downloaded
# cannot download
# Img 25  is downloaded
# Img 26  is downloaded
# Img 27  is downloaded
# Img 28  is downloaded
# Img 29  is downloaded
# Img 30  is downloaded
# Img 31  is downloaded
# Img 32  is downloaded
# Img 33  is downloaded
# Img 34  is downloaded
# Img 35  is downloaded
# cannot download
# Img 36  is downloaded
# Img 37  is downloaded
# Img 38  is downloaded
# Img 39  is downloaded
# Img 40  is downloaded
# ...

# %%
#换品类如果还能爬到就不用改header
req_header = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
    'Cookie':'session-id=459-9422158-4293202; i18n-prefs=CNY; ubid-acbcn=458-1711333-0590306; x-wl-uid=1BVMuH1eD98yTaHxVWUa/As36Kg8hzSgi9dRsHFksFLBOuF4JKeRw9RTxJzJlbZckTnjcQh8hfBQ=; lc-acbcn=zh_CN; session-token="6Uu78o6qyx1yVWI2ZCXdCmmRoBOpdWCjLTbRnWPeyFPJ6rTE1neJX4ROLE2znioK4b147Acg/Vt5+5fy87VS80/cBZ9tIJbcQSe7T34qY+9oRCQIuCJoE8pMMoalIwgjMF1YX93IpelJIo7f4YoXWtBRLc89HSHHbn8XlKiHcgQCY2ezelYFeGNfeJk+Fjr2hsYdwxd1IDOyPFmC2wgvNYjOSXR8wdT3f9SJ6VNrC+98w+nphVNcfA=="; session-id-time=2082787201l; csm-hit=tb:EENB0C0RRGJNBEFBQJN7+s-B4R2DY9NWH2TJMYZVJBX|1587389226614&t:1587389226614&adb:adblk_no',
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9'
}

#图片标号，每个品类进行一轮标号
n = 46

#设置页数
i = 2

#设置超时时间30s
socket.setdefaulttimeout(30)

#设置超时重试
#s = requests.Session()
#s.mount('http://', HTTPAdapter(max_retries=3))
#s.mount('https://', HTTPAdapter(max_retries=3))

#range：要爬的页数，根据需要改
while n < 1441:
    #换品类需要改URL,第一页因为URL会跳转之后再显示，爬不到，实际从第二页开始
    url = 'https://www.amazon.cn/s?rh=n%3A2016156051%2Cn%3A%212016157051%2Cn%3A865184051%2Cn%3A100275071%2Cn%3A100276071%2Cn%3A1894146071&page='+str(i)+'&language=en&qid=1592758594&ref=lp_1894146071_pg_'+str(i)
    i += 1
    try:
        response = requests.get(url,headers=req_header,timeout=5)
        soup = BeautifulSoup(response.text)
        srclist = []
        for x in soup.find_all(name='img', attrs={'data-image-latency':'s-product-image'}):
            link = x.get('src')
            if '.jpg' in link:
                srclist.append(link)
        for imgurl in srclist:
            try:
                urllib.request.urlretrieve(imgurl, '/Users/hu/Desktop/project/img/'+str(n)+'.jpg')
                print('Img',str(n),' is downloaded','Page',i-1)
                n += 1
            except socket.timeout:
                count = 1
                while count <= 5:
                    try:
                        urllib.request.urlretrieve(imgurl,'/Users/hu/Desktop/project/img/'+str(n)+'.jpg')                                                
                        break
                    except socket.timeout:
                        err_info = 'Reloading for %d time'%count if count == 1 else 'Reloading for %d times'%count
                        print(err_info)
                        count += 1
                if count > 5:
                    print("downloading picture fialed!")
            except:
                print('cannot download')
    except requests.exceptions.RequestException as e:
        print(e)
# Out:
# Img 46  is downloaded Page 2
# Img 47  is downloaded Page 2
# Img 48  is downloaded Page 2
# Img 49  is downloaded Page 2
# Img 50  is downloaded Page 2
# Img 51  is downloaded Page 2
# Img 52  is downloaded Page 2
# Img 53  is downloaded Page 2
# Img 54  is downloaded Page 2
# Img 55  is downloaded Page 2
# Img 56  is downloaded Page 2
# Img 57  is downloaded Page 2
# Img 58  is downloaded Page 2
# Img 59  is downloaded Page 2
# Img 60  is downloaded Page 2
# Img 61  is downloaded Page 2
# Img 62  is downloaded Page 2
# Img 63  is downloaded Page 2
# Img 64  is downloaded Page 2
# Img 65  is downloaded Page 2
# Img 66  is downloaded Page 2
# Img 67  is downloaded Page 2
# Img 68  is downloaded Page 2
# Img 69  is downloaded Page 2
# Img 70  is downloaded Page 2
# Img 71  is downloaded Page 2
# Img 72  is downloaded Page 2
# Img 73  is downloaded Page 2
# Img 74  is downloaded Page 2
# Img 75  is downloaded Page 2
# Img 76  is downloaded Page 2
# Img 77  is downloaded Page 2
# ...
